# %%
import pandas as pd
df = pd.read_csv("Mobile Price Dataset.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  four_g  int_memory  \
# 0               842   0.0          2.2       0.0     1.0           7
# 1              1021   NaN          0.5       NaN     1.0          41
# 2               615   0.0          2.5       0.0     0.0          10
# 3              1821   0.0          1.2       0.0     1.0          44
# 4              1859   0.0          0.5       NaN     0.0          22
# ...             ...   ...          ...       ...     ...         ...
# 2007            804   1.0          0.8       1.0     1.0          41
# 2008           1713   0.0          2.5       1.0     0.0          27
# 2009           1023   1.0          0.7       0.0     1.0          63
# 2010           1283   1.0          2.4       1.0     1.0          33
# 2011           1470   1.0          1.7       1.0     0.0          45
#
#       mobile_wt  n_cores  pc  px_height  px_width     ram  sc_h  sc_w  wifi  \
# 0         188.0      2.0   2       20.0     756.0  2549.0     9     7     1
# 1         145.0      5.0   6     1263.0    1716.0  2603.0    11     2     0
# 2         131.0      6.0   9     1216.0    1786.0  2769.0    16     8     0
# 3         141.0      2.0  14     1208.0    1212.0  1411.0     8     2     0
# 4         164.0      1.0   7     1004.0    1654.0     NaN    17     1     0
# ...         ...      ...  ..        ...       ...     ...   ...   ...   ...
# 2007       89.0      1.0  13      709.0     818.0  2027.0    11     5     0
# 2008      127.0      7.0   3      729.0     974.0  2406.0    13    10     1
# 2009      153.0      7.0   8      367.0    1985.0  3155.0    11    10     1
# 2010       93.0      3.0  15      510.0     980.0   773.0    17     7     0
# 2011      121.0      1.0   9      777.0    1090.0  3259.0    10     1     1
#
#       price_range  Unnamed: 16
# 0               1          NaN
# 1               2          NaN
# 2               2          NaN
# 3               1          NaN
# 4               1          NaN
# ...           ...          ...
# 2007            1          NaN
# 2008            2          NaN
# 2009            3          NaN
# 2010            0          NaN
# 2011            3          NaN
#
# [2012 rows x 17 columns]

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  four_g  int_memory  mobile_wt  \
# 0            842   0.0          2.2       0.0     1.0           7      188.0
# 1           1021   NaN          0.5       NaN     1.0          41      145.0
# 2            615   0.0          2.5       0.0     0.0          10      131.0
# 3           1821   0.0          1.2       0.0     1.0          44      141.0
# 4           1859   0.0          0.5       NaN     0.0          22      164.0
#
#    n_cores  pc  px_height  px_width     ram  sc_h  sc_w  wifi  price_range  \
# 0      2.0   2       20.0     756.0  2549.0     9     7     1            1
# 1      5.0   6     1263.0    1716.0  2603.0    11     2     0            2
# 2      6.0   9     1216.0    1786.0  2769.0    16     8     0            2
# 3      2.0  14     1208.0    1212.0  1411.0     8     2     0            1
# 4      1.0   7     1004.0    1654.0     NaN    17     1     0            1
#
#    Unnamed: 16
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2012 entries, 0 to 2011
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2012 non-null   int64
#  1   blue           1959 non-null   float64
#  2   clock_speed    2012 non-null   float64
#  3   dual_sim       2004 non-null   float64
#  4   four_g         1967 non-null   float64
#  5   int_memory     2012 non-null   int64
#  6   mobile_wt      2007 non-null   float64
#  7   n_cores        1998 non-null   float64
#  8   pc             2012 non-null   int64
#  9   px_height      2007 non-null   float64
#  10  px_width       2007 non-null   float64
#  11  ram            1987 non-null   float64
#  12  sc_h           2012 non-null   int64
#  13  sc_w           2012 non-null   int64
#  14  wifi           2012 non-null   int64
#  15  price_range    2012 non-null   int64
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(10), int64(7)
# memory usage: 267.3 KB

# %%
df.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim       four_g  \
# count    2012.000000  1959.000000  2012.000000  2004.000000  1967.000000
# mean     1238.815606     0.495151     1.522913     0.509481     0.511439
# std       439.639747     0.500104     0.816334     0.500035     0.499996
# min       501.000000     0.000000     0.500000     0.000000     0.000000
# 25%       851.000000     0.000000     0.700000     0.000000     0.000000
# 50%      1228.000000     0.000000     1.500000     1.000000     1.000000
# 75%      1617.000000     1.000000     2.200000     1.000000     1.000000
# max      1998.000000     1.000000     3.000000     1.000000     1.000000
#
#         int_memory    mobile_wt      n_cores           pc    px_height  \
# count  2012.000000  2007.000000  1998.000000  2012.000000  2007.000000
# mean     32.074553   140.324365     4.678679     9.922962   646.660189
# std      18.137094    35.389063     3.619185     6.065573   443.489043
# min       2.000000    80.000000     0.000000     0.000000     0.000000
# 25%      16.000000   109.000000     3.000000     5.000000   284.500000
# 50%      32.000000   141.000000     4.000000    10.000000   570.000000
# 75%      48.000000   170.000000     7.000000    15.000000   949.000000
# max      64.000000   200.000000    50.000000    20.000000  1960.000000
#
#           px_width          ram         sc_h         sc_w         wifi  \
# count  2007.000000  1987.000000  2012.000000  2012.000000  2012.000000
# mean   1252.297459  2124.542023    12.313121     5.778330     0.506958
# std     431.774300  1086.949980     4.209502     4.356396     0.500076
# min     500.000000   256.000000     5.000000     0.000000     0.000000
# 25%     876.500000  1208.500000     9.000000     2.000000     0.000000
# 50%    1247.000000  2137.000000    12.000000     5.000000     1.000000
# 75%    1633.000000  3076.500000    16.000000     9.000000     1.000000
# max    1998.000000  3998.000000    19.000000    18.000000     1.000000
#
#        price_range  Unnamed: 16
# count  2012.000000          0.0
# mean      1.498509          NaN
# std       1.118756          NaN
# min       0.000000          NaN
# 25%       0.000000          NaN
# 50%       1.000000          NaN
# 75%       2.250000          NaN
# max       3.000000          NaN

# %%
df.loc[15:30]
# Out:
#     battery_power  blue  clock_speed  dual_sim  four_g  int_memory  mobile_wt  \
# 15            838   0.0          0.5       0.0     1.0          13      196.0
# 16            595   0.0          0.9       1.0     1.0          23      121.0
# 17           1131   1.0          0.5       1.0     0.0          49      101.0
# 18            682   1.0          0.5       0.0     0.0          19      121.0
# 19            772   0.0          1.1       1.0     0.0          39       81.0
# 20           1709   1.0          2.1       0.0     0.0          13      156.0
# 21           1949   0.0          2.6       1.0     0.0          47      199.0
# 22           1602   1.0          2.8       1.0     1.0          38      114.0
# 23            503   0.0          1.2       1.0     1.0           8      111.0
# 24            961   1.0          1.4       1.0     1.0          57      114.0
# 25            519   1.0          1.6       1.0     1.0          51      132.0
# 26            956   0.0          0.5       0.0     1.0          41      143.0
# 27           1453   0.0          1.6       1.0     1.0          52       96.0
# 28            851   0.0          0.5       0.0     0.0          21      200.0
# 29           1579   1.0          0.5       1.0     0.0           5       88.0
# 30           1568   1.0          0.5       0.0     0.0          33      150.0
#
#     n_cores  pc  px_height  px_width     ram  sc_h  sc_w  wifi  price_range  \
# 15      8.0   4      984.0    1850.0  3554.0    10     9     1            3
# 16      3.0  17      441.0     810.0  3752.0    10     2     0            3
# 17      5.0  18      658.0     878.0  1835.0    19    13     0            1
# 18      4.0  11      902.0    1064.0  2337.0    11     1     1            1
# 19      7.0  14     1314.0    1854.0  2819.0    17    15     0            3
# 20      2.0   2      974.0    1385.0  3283.0    17     1     0            3
# 21      4.0   7      407.0     822.0  1433.0    11     5     1            1
# 22      3.0  20      466.0     788.0  1037.0     8     7     0            0
# 23      3.0  13      201.0    1245.0  2583.0    11     0     0            1
# 24      8.0   3      291.0    1434.0  2782.0    18     9     1            2
# 25      4.0  19      550.0     645.0  3763.0    16     1     1            3
# 26      7.0   6      511.0    1075.0  3286.0    17     8     0            3
# 27      2.0  18      187.0    1311.0     NaN    10     1     1            2
# 28      5.0   7     1171.0    1263.0   478.0    12     7     1            0
# 29      7.0   9     1358.0    1739.0  3532.0    17    11     1            3
# 30      8.0  20      413.0     654.0   508.0     5     1     1            0
#
#     Unnamed: 16
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN

# %%
df.isnull().sum()
# Out:
# battery_power       0
# blue               53
# clock_speed         0
# dual_sim            8
# four_g             45
# int_memory          0
# mobile_wt           5
# n_cores            14
# pc                  0
# px_height           5
# px_width            5
# ram                25
# sc_h                0
# sc_w                0
# wifi                0
# price_range         0
# Unnamed: 16      2012
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = df[col].fillna(df[col].mode()[0])
    else:
        df[col] = df[col].fillna(df[col].mean())

# %%
df.isnull().sum()
# Out:
# battery_power       0
# blue                0
# clock_speed         0
# dual_sim            0
# four_g              0
# int_memory          0
# mobile_wt           0
# n_cores             0
# pc                  0
# px_height           0
# px_width            0
# ram                 0
# sc_h                0
# sc_w                0
# wifi                0
# price_range         0
# Unnamed: 16      2012
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in df.select_dtypes(include=['int64', 'float64']).columns:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower_bound, upper_bound)

# %%
import matplotlib.pyplot as plt

# %%
df['price_range'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(6,6)
)
plt.title("Price Range Distribution")
plt.show()

# %%
df['blue'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(6,6)
)
plt.title("Bluetooth Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))

df['ram'].hist(bins=20)

plt.title('RAM Distribution')
plt.xlabel('RAM')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    df.corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')
plt.show()

# %%
df.to_csv('cleaned_dataset.csv', index=False)
